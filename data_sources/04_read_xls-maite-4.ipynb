# %% [markdown]
# # XLS and XLSX files. . Exercise 4
#
# Pandas documentation: https://pandas.pydata.org/docs/index.html
#
# Pandas API reference: https://pandas.pydata.org/docs/reference/index.html#api

# %%
# import pandas library
import pandas as pd

# %% [markdown]
# ### Sales Dataset
#
# **Source**: Tableau Community
#
# https://community.tableau.com/s/question/0D54T00000CWeX8SAL/sample-superstore-sales-excelxls

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /home/xuwira30/miniconda3
# sistemas              *  /home/xuwira30/miniconda3/envs/sistemas

# %%
# Load XLS file (from local filesystem)
df = pd.read_excel('../datasets/sample_superstore.xls')

# %%
# Load XLS file (from GitHub repo)
df = pd.read_excel('https://github.com/bigdatawirtz/sistemas-bigdata-2023/raw/main/datasets/sample_superstore.xls', 'Orders')

# %%
# show DataFrame
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
# Show the 3 first rows filas
df.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62         2
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
# 2       0.0    6.8714
#
# [3 rows x 21 columns]

# %%
# Show 5 random rows
df.sample(n = 5) # sample() Devuelve registro seleccionado de forma aleatoria
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2781    2782  CA-2017-146724 2017-11-20 2017-11-27  Standard Class
# 2786    2787  CA-2015-149972 2015-09-21 2015-09-23     First Class
# 524      525  US-2016-139486 2016-05-21 2016-05-23     First Class
# 4768    4769  CA-2017-158883 2017-06-02 2017-06-03        Same Day
# 9667    9668  CA-2016-126270 2016-04-23 2016-04-27  Standard Class
#
#      Customer ID     Customer Name      Segment        Country          City  \
# 2781    HG-15025     Hunter Glantz     Consumer  United States     Lakeville
# 2786    CD-12790   Cynthia Delaney  Home Office  United States   Los Angeles
# 524     LH-17155  Logan Haushalter     Consumer  United States   Los Angeles
# 4768    CS-11860   Cari Schnelling     Consumer  United States  Jacksonville
# 9667    AF-10870      Art Ferguson     Consumer  United States  San Clemente
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 2781  ...       55044  Central  OFF-AR-10001026  Office Supplies          Art
# 2786  ...       90036     West  OFF-FA-10002763  Office Supplies    Fasteners
# 524   ...       90032     West  TEC-AC-10003832       Technology  Accessories
# 4768  ...       28540    South  OFF-PA-10004733  Office Supplies        Paper
# 9667  ...       92672     West  OFF-BI-10002764  Office Supplies      Binders
#
#                                            Product Name   Sales  Quantity  \
# 2781  Sanford Uni-Blazer View Highlighters, Chisel T...  22.000        10
# 2786    Advantus Map Pennant Flags and Round Head Tacks   7.900         2
# 524   Imation 16GB Mini TravelDrive USB 2.0 Flash Drive  66.260         2
# 4768                     Things To Do Today Spiral Book  25.344         4
# 9667  Recycled Pressboard Report Cover with Reinforc...  18.088         7
#
#       Discount   Profit
# 2781       0.0   9.6800
# 2786       0.0   2.5280
# 524        0.0  27.1666
# 4768       0.2   9.1872
# 9667       0.2   6.5569
#
# [5 rows x 21 columns]

# %%
# From the last 10 rows, show the 5 first ones
df.tail(10).head(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9985    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9986    ML-17410      Maris LaWare   Consumer  United States  Los Angeles
# 9987    RA-19885      Ruben Ausman  Corporate  United States       Athens
# 9988    RA-19885      Ruben Ausman  Corporate  United States       Athens
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 9984  ...       11561    East  OFF-LA-10003766  Office Supplies       Labels
# 9985  ...       11561    East  OFF-SU-10000898  Office Supplies     Supplies
# 9986  ...       90008    West  TEC-AC-10003399       Technology  Accessories
# 9987  ...       30605   South  TEC-AC-10001539       Technology  Accessories
# 9988  ...       30605   South  TEC-PH-10004006       Technology       Phones
#
#                                            Product Name   Sales  Quantity  \
# 9984                     Self-Adhesive Removable Labels   31.50        10
# 9985  Acme Hot Forged Carbon Steel Scissors with Nic...   55.60         4
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.24         1
# 9987  Logitech G430 Surround Sound Gaming Headset wi...   79.99         1
# 9988                    Panasonic KX - TS880B Telephone  206.10         5
#
#       Discount   Profit
# 9984       0.0  15.1200
# 9985       0.0  16.1240
# 9986       0.0  15.2208
# 9987       0.0  28.7964
# 9988       0.0  55.6470
#
# [5 rows x 21 columns]

# %%
# Show 3 random rows from the first 50 ones
df.head(50).sample(3)
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 31      32  US-2015-150630 2015-09-17 2015-09-21  Standard Class    TB-21520
# 5        6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#       Customer Name   Segment        Country          City  ... Postal Code  \
# 0       Claire Gute  Consumer  United States     Henderson  ...       42420
# 31  Tracy Blumstein  Consumer  United States  Philadelphia  ...       19140
# 5   Brosina Hoffman  Consumer  United States   Los Angeles  ...       90032
#
#     Region       Product ID         Category Sub-Category  \
# 0    South  FUR-BO-10001798        Furniture    Bookcases
# 31    East  OFF-AR-10004042  Office Supplies          Art
# 5     West  FUR-FU-10001487        Furniture  Furnishings
#
#                                          Product Name    Sales  Quantity  \
# 0                   Bush Somerset Collection Bookcase  261.960         2
# 31  BOSTON Model 1800 Electric Pencil Sharpeners, ...   86.304         6
# 5   Eldon Expressions Wood and Plastic Desk Access...   48.860         7
#
#     Discount   Profit
# 0        0.0  41.9136
# 31       0.2   9.7092
# 5        0.0  14.1694
#
# [3 rows x 21 columns]

# %%
# Show info about column data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
# zip code type: 
type(df['Postal Code'][0])
# Out:
# numpy.int64

# %%
# Discount type: 
type(df['Discount'][0])
# Out:
# numpy.float64

# %%
# Country data type: 
type(df['Country'][0])
# Out:
# str

# %%
# Show column names
df.columns.values
# Out:
# array(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'], dtype=object)

# %%
# Select and show 5 different random cities
df['City'].sample(5)
# Out:
# 2957    Springfield
# 8752    Tallahassee
# 5683         Athens
# 8228           Troy
# 2553       Columbia
# Name: City, dtype: object

# %%
# Show the different countries that appear in the data
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
# Show the different categories
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
# Select client id, name and city
df[['Customer ID', 'Customer Name', 'City']]
# Out:
#      Customer ID     Customer Name             City
# 0       CG-12520       Claire Gute        Henderson
# 1       CG-12520       Claire Gute        Henderson
# 2       DV-13045   Darrin Van Huff      Los Angeles
# 3       SO-20335    Sean O'Donnell  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell  Fort Lauderdale
# ...          ...               ...              ...
# 9989    TB-21400  Tom Boeckenhauer            Miami
# 9990    DB-13060       Dave Brooks       Costa Mesa
# 9991    DB-13060       Dave Brooks       Costa Mesa
# 9992    DB-13060       Dave Brooks       Costa Mesa
# 9993    CC-12220      Chris Cortes      Westminster
#
# [9994 rows x 3 columns]

# %%
# Select Order ID (as Dataframe)
df[['Order ID']]
# Out:
#             Order ID
# 0     CA-2016-152156
# 1     CA-2016-152156
# 2     CA-2016-138688
# 3     US-2015-108966
# 4     US-2015-108966
# ...              ...
# 9989  CA-2014-110422
# 9990  CA-2017-121258
# 9991  CA-2017-121258
# 9992  CA-2017-121258
# 9993  CA-2017-119914
#
# [9994 rows x 1 columns]

# %%
# Count elements in Series "Region"
df['Region'].count()
# Out:
# 9994

# %%
# Show elementes from "Region" Series
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
# Count different elements in Series "Region"
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
# Create a Series with quantities in each order line and show the result
#df[['Quantity']].value_counts()
# Out:
# Quantity
# 3           2409
# 2           2402
# 5           1230
# 4           1191
# 1            899
# 7            606
# 6            572
# 9            258
# 8            257
# 10            57
# 11            34
# 14            29
# 13            27
# 12            23
# Name: count, dtype: int64

# %%
# Show the lines with quantities greater than 2
df[['Quantity']].query('Quantity>2')
# Out:
#       Quantity
# 1            3
# 3            5
# 5            7
# 6            4
# 7            6
# ...        ...
# 9984        10
# 9985         4
# 9988         5
# 9989         3
# 9992         4
#
# [6693 rows x 1 columns]

# %%
# Show only the DataFrame lines with subcategory  "Tables"
df[['Sub-Category']].head().tail(2).head(1)
# Out:
#   Sub-Category
# 3       Tables

# %%
# Show the cities with orders including "Tables"
#df[['City']].query('Category')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/collections/__init__.py:1014, in ChainMap.__getitem__(self, key)
#    1013         pass
# -> 1014 return self.__missing__(key)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/collections/__init__.py:1006, in ChainMap.__missing__(self, key)
#    1005 def __missing__(self, key):
# -> 1006     raise KeyError(key)
#
# KeyError: 'Category'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'Category'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[102], line 2
#       1 # Show the cities with orders including "Tables"
# ----> 2 df[['City']].query('Category')
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/frame.py:4599, in DataFrame.query(self, expr, inplace, **kwargs)
#    4597 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4598 kwargs["target"] = None
# -> 4599 res = self.eval(expr, **kwargs)
#    4601 try:
#    4602     result = self.loc[res]
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/frame.py:4725, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4722     kwargs["target"] = self
#    4723 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4725 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/expr.py:808, in Expr.__init__(self, expr, engine, parser, env, level)
#     806 self.parser = parser
#     807 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 808 self.terms = self.parse()
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/expr.py:827, in Expr.parse(self)
#     823 def parse(self):
#     824     """
#     825     Parse an expression.
#     826     """
# --> 827     return self._visitor.visit(self.expr)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/expr.py:417, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     415     raise SyntaxError("only a single expression is allowed")
#     416 expr = node.body[0]
# --> 417 return self.visit(expr, **kwargs)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/expr.py:420, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     419 def visit_Expr(self, node, **kwargs):
# --> 420     return self.visit(node.value, **kwargs)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/expr.py:411, in BaseExprVisitor.visit(self, node, **kwargs)
#     409 method = f"visit_{type(node).__name__}"
#     410 visitor = getattr(self, method)
# --> 411 return visitor(node, **kwargs)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/expr.py:544, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     543 def visit_Name(self, node, **kwargs):
# --> 544     return self.term_type(node.id, self.env, **kwargs)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and res.ndim > 2:
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/computation/scope.py:244, in Scope.resolve(self, key, is_local)
#     242     return self.temps[key]
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'Category' is not defined

# %%
# Create a variable (type Series) of cities with orders including Tables. Show 5 random elements.

# %%
# Create a variable (type DataFrame) of cities with orders including Chairs. Show the 3 last elements.

# %%
# Show all the order lines including Phones to 'Los Angeles'

# %%
# Show 10 random order lines with Phones or Tables

# %%
# Select the second row of the dataframe

# %%
# Select the third, seventh and 24 row of the dataset

# %%
# create a dataframe (sales) with the client name, city, product name and quantity from West region

# %%
# Select the second row from the previous DataFrame (sales) using position

# %%
# Select the second row from the previous DataFrame (sales) using index

# %%
# Think about what's the best column in the spreadsheet to use it as an index and load the file again in a new DataFrame

# %%
# Select the fifth row

# %%
# Select rows from the third to the seventh one

# %%
# Selecdt penultimate row
df.head().tail(2).head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#     Customer Name   Segment        Country             City  ... Postal Code  \
# 3  Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
#
#    Region       Product ID   Category Sub-Category  \
# 3   South  FUR-TA-10000577  Furniture       Tables
#
#                                     Product Name     Sales  Quantity  \
# 3  Bretford CR4500 Series Slim Rectangular Table  957.5775         5
#
#    Discount   Profit
# 3      0.45 -383.031
#
# [1 rows x 21 columns]

# %%
# Select, give the last 5 rows, all but the last one.

# %%
# Depending on what we need, we can use loc or iloc
# loc <- work with index/labels
# iloc <- work with positions

# %%
# Write to XLS all the sales in the State of California

# %%
# Give a name to the sheet ('California')

# %%
# Save the sales rows in the west or south. 
# Save the product name, identifier, quantity and discount. 
# Save the result in a file sales_WS.xlsx
# Try to do it all in a single row
